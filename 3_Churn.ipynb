# %% [raw]
# Список признаков
# state - код штата
# account_lenght - как долго клиент обслуживается в компании
# area_code - префикс номера телефона
# phone_number - номер телефона
# international_plan - международный роуминг (подключен или нет)
# voice_mail_plan - голосовая почта (подключена или нет)
# number_vmail_messages - количество голосовых сообщений
# total_day_minutes - длительность разговора днем
# total_day_calls - общее количество звонков в день.
# total_day_charge - общая сумма оплаты за услуги днем.
# total_eve_minutes - длительность разговоров вечером.
# total_eve_calls - общее количество вызовов вечером.
# total_eve_charge - общая сумма оплаты услуг вечером.
# total_night_minutes - длительность разговоров ночью.
# total_night_calls - общее количество звонков в ночное время
# total_night_charge - общая сумма оплаты за услуги ночью
# total_intl_minutes - длительность международных разговоров
# total_intl_calls - общее количество интернациональных бесед
# total_intl_charge - общая сумма оплаты международных разговоров
# customer_service_calls - количество обращений в сервисный центр
# churn - признак оттока клиентов, бинарная переменная (1 – утрата клиента, то есть отток)

# %% [markdown]
# Подключаем нужные библиотеки

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Скичваем и проверяем данные на целостность

# %%
df = pd.read_csv("churn_dataset.csv")

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df['International plan'] = df['International plan'].map({'Yes':True ,'No':False})
df['Voice mail plan'] = df['Voice mail plan'].map({'Yes':True ,'No':False})
df['Churn'] = df['Churn'].map({True:1 ,False:0})

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   bool
#  4   Voice mail plan         3333 non-null   bool
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# Посмотрим на статистические данные и на отток клиентов

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df["Churn"].value_counts()
# Out:
# 0    2850
# 1     483
# Name: Churn, dtype: int64

# %%
df["Churn"].value_counts().plot(kind="bar", label="Churn")
plt.legend()
plt.title("Распределение оттока клиентов");

# %%
df['Churn'].mean()
# Out:
# 0.14491449144914492

# %%
df[df['Churn'] == 1].mean()
# Out:
# Account length            102.664596
# Area code                 437.817805
# International plan          0.283644
# Voice mail plan             0.165631
# Number vmail messages       5.115942
# Total day minutes         206.914079
# Total day calls           101.335404
# Total day charge           35.175921
# Total eve minutes         212.410145
# Total eve calls           100.561077
# Total eve charge           18.054969
# Total night minutes       205.231677
# Total night calls         100.399586
# Total night charge          9.235528
# Total intl minutes         10.700000
# Total intl calls            4.163561
# Total intl charge           2.889545
# Customer service calls      2.229814
# Churn                       1.000000
# dtype: float64

# %% [markdown]
# Построим граффик корреляции ( предварительно убираем не численные данные)

# %%
corr_matrix = df.drop(
    ["State", "International plan", "Voice mail plan", "Area code"], axis=1
).corr()

# %%
sns.heatmap(corr_matrix);

# %% [raw]
# Мы видим логичную взаимосвясь между количеством проговоренных минут и их оплатой
# Стоит убрать одни из созависимых признаков

# %% [markdown]
# Посмотрим на распределение признаков

# %%
features = list(
    set(df.columns)
    - set(
        [
            "State",
            "International plan",
            "Voice mail plan",
            "Area code",
            "Total day charge",
            "Total eve charge",
            "Total night charge",
            "Total intl charge",
            "Churn",
        ]
    )
)

df[features].hist(figsize=(20, 12));

# %% [markdown]
# У большинства нормальное распределение, кроме Customer service calls, Number vmail messages, Total intl calls.

# %% [markdown]
# Посмотрим отношения оттока с каждым признаком

# %%
sns.pairplot(df[features + ["Churn"]], hue="Churn");

# %% [markdown]
#  Рассмотрим распределение на ушедших и нет с количественными данными

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16, 10))

for idx, feat in enumerate(features):
    sns.boxplot(x="Churn", y=feat, data=df, ax=axes[int(idx / 4), idx % 4])
    axes[int(idx / 4), idx % 4]
    axes[int(idx / 4), idx % 4].set_xlabel("Churn")
    axes[int(idx / 4), idx % 4].set_ylabel(feat);

# %% [markdown]
# Можем заметить наибольшую разницу у Total day minutes, Customer service calls и Number vmail messages

# %%
sns.boxplot(x="Churn", y="Total day minutes", data=df);

# %% [markdown]
# Можно заметить, что те, кто больше пользуются связью, чаще уходят ( возможно тарифы слишком большие)

# %%
sns.countplot(x="Customer service calls", hue="Churn", data=df);

# %% [markdown]
# Можем заметить, что на 4 обращении доля оттока резко возрастает

# %%
_, axes = plt.subplots(1, 2, sharey=True, figsize=(16, 6))

sns.countplot(x="International plan", hue="Churn", data=df, ax=axes[0])
sns.countplot(x="Voice mail plan", hue="Churn", data=df, ax=axes[1]);

# %% [markdown]
# Можем заметить, что у тех, кто подключен к International plan, меньше лояльности

# %% [markdown]
# Давайте узнаем как решающее дерево распределит по значимости признаки

# %% [markdown]
# Поменяем назвние штата на код

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df['State'])
df['State'] = le.transform(df['State'])

# %%
df.head()
# Out:
#    State  Account length  Area code  International plan  Voice mail plan  \
# 0     16             128        415               False             True
# 1     35             107        415               False             True
# 2     31             137        415               False            False
# 3     35              84        408                True            False
# 4     36              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# Разделим данные на обучающую и тестовую выборку

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df.iloc[:, :-1], df['Churn'], random_state=0)

# %% [raw]
# Импортируем модель решающего дерева
# И обучим модель

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train);

# %% [markdown]
# Выведем схему принятия решений нашей модели

# %%
tree.export_graphviz(dtc, 
out_file='churn_tree.dot', feature_names=df.columns[:-1], filled=True)
# !dot -Tpng 'churn_tree.dot' -o 'churn_tree.png'

# %%
# !feh 'churn_tree.png'

# %% [raw]
# Вывод:
#     Действительно стоит задуматься о тарифах на звонки и больше внимания обращать на работу сервесного центра
#     Так же возможно стоит обратить внимание на тарифы для роуминга
